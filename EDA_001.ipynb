# %%
import pandas as pd
import numpy as np
import seaborn  as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\hp\Desktop\dataset\CLEANED DATA GOOGLEPLAYSTORE")

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy=df

# %%
df_copy.drop_duplicates()
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy.shape
# Out:
# (10358, 12)

# %%
numericFeature= [feature for feature in df_copy.columns if df_copy[feature].dtype!='O']

# %%
numericFeature
# Out:
# ['Rating', 'Size', 'Installs']

# %%
df_numeric=pd.DataFrame(df_copy[numericFeature])

# %%
df_numeric
# Out:
#        Rating     Size  Installs
# 0         4.1  19000.0     10000
# 1         3.9  14000.0    500000
# 2         4.7   8700.0   5000000
# 3         4.5  25000.0  50000000
# 4         4.3   2800.0    100000
# ...       ...      ...       ...
# 10353     4.5  53000.0      5000
# 10354     5.0   3600.0       100
# 10355     NaN   9500.0      1000
# 10356     4.5      NaN      1000
# 10357     4.5  19000.0  10000000
#
# [10358 rows x 3 columns]

# %%
categorial_feature=[feature for feature in df_copy.columns  if df_copy[feature].dtypes=='O']

# %%
df_categorial=pd.DataFrame(df_copy[categorial_feature])

# %%
df_categorial
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy['Type'].value_counts( normalize=True)*100
# Out:
# Type
# Free    92.604036
# Paid     7.386309
# 0        0.009655
# Name: proportion, dtype: float64

# %%
plt.pie(df_copy['Type'].value_counts( normalize=True)*100, )
# Out:
# ([<matplotlib.patches.Wedge at 0x21ef4af6060>,
# ...
#  [Text(-1.0704404799940266, 0.2532926741738855, ''),
#   Text(1.0703635942351382, -0.25361738137603373, ''),
#   Text(1.0999999493813082, -0.0003337081351652716, '')])

# %%
df_copy['Category'].value_counts( normalize=True)*100
# Out:
# Category
# FAMILY                 18.758448
# GAME                   10.822553
# TOOLS                   8.138637
# BUSINESS                4.122417
# MEDICAL                 3.938984
# PRODUCTIVITY            3.929330
# PERSONALIZATION         3.745897
# LIFESTYLE               3.601081
# COMMUNICATION           3.533501
# FINANCE                 3.475574
# SPORTS                  3.388685
# PHOTOGRAPHY             3.108708
# HEALTH_AND_FITNESS      2.954238
# SOCIAL                  2.703225
# NEWS_AND_MAGAZINES      2.548755
# TRAVEL_AND_LOCAL        2.288087
# BOOKS_AND_REFERENCE     2.220506
# SHOPPING                2.162580
# DATING                  1.892257
# VIDEO_PLAYERS           1.689515
# MAPS_AND_NAVIGATION     1.322649
# EDUCATION               1.255069
# FOOD_AND_DRINK          1.197142
# ENTERTAINMENT           1.071635
# AUTO_AND_VEHICLES       0.820622
# LIBRARIES_AND_DEMO      0.820622
# WEATHER                 0.791659
# HOUSE_AND_HOME          0.772350
# ...

# %%
plt.pie(df_copy['Category'].value_counts( normalize=True)*100)
# Out:
# ([<matplotlib.patches.Wedge at 0x21ef49c3bc0>,
# ...
#  [Text(0.9144543286733923, 0.6113700031654281, ''),
#   Text(0.05735842555103119, 1.0985035325470314, ''),
#   Text(-0.5688630644075734, 0.9414854294957651, ''),
#   Text(-0.8809316154601086, 0.6587560162023901, ''),
#   Text(-1.0178878191076992, 0.41701845008605076, ''),
#   Text(-1.088984177650896, 0.15528509531182386, ''),
#   Text(-1.0945612140389063, -0.10925085226979091, ''),
#   Text(-1.040541339250224, -0.356754427178347, ''),
#   Text(-0.9352180417483872, -0.5791089831701044, ''),
#   Text(-0.7861469152240412, -0.7693978344677898, ''),
#   Text(-0.6033028624294086, -0.919796529774103, ''),
#   Text(-0.40432863641925393, -1.022994796551452, ''),
#   Text(-0.20333935607106973, -1.081042601506806, ''),
#   Text(-0.0090075868467832, -1.099963119099544, ''),
#   Text(0.1717817075140199, -1.0865040473756036, ''),
#   Text(0.3342661632388389, -1.0479819331045674, ''),
#   Text(0.4788606970333422, -0.9902991633020508, ''),
# ...

# %%
sns.countplot(x=df_copy['Type'])
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
sns.displot(x=df_copy['Content Rating'],kde=True)

# %%
plt.figure( figsize=(15,15))
plt.suptitle("UNIVARIATE ANALYSIS OF FEATURES")
for i in range (0, len(numericFeature) ):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x=df_copy[numericFeature[i]], fill =True,color='r')
    plt.xlabel(numericFeature[i])
    plt.tight_layout()

# %%
df_copy['Category'].value_counts().plot.pie(figsize=(15,15),autopct="%1.1f")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# 1. top  TEN CATEGORY OF APP

# %%
cat=df_copy['Category'].value_counts()[:10]    ## top 10 category of app

# %%
df_cat=pd.DataFrame(df_copy['Category'].value_counts() )

# %%
cat=pd.DataFrame(df_copy['Category'].value_counts() )

# %%
df_cat
# Out:
#                      count
# Category
# FAMILY                1943
# GAME                  1121
# TOOLS                  843
# BUSINESS               427
# MEDICAL                408
# PRODUCTIVITY           407
# PERSONALIZATION        388
# LIFESTYLE              373
# COMMUNICATION          366
# FINANCE                360
# SPORTS                 351
# PHOTOGRAPHY            322
# HEALTH_AND_FITNESS     306
# SOCIAL                 280
# NEWS_AND_MAGAZINES     264
# TRAVEL_AND_LOCAL       237
# BOOKS_AND_REFERENCE    230
# SHOPPING               224
# DATING                 196
# VIDEO_PLAYERS          175
# MAPS_AND_NAVIGATION    137
# EDUCATION              130
# FOOD_AND_DRINK         124
# ENTERTAINMENT          111
# AUTO_AND_VEHICLES       85
# LIBRARIES_AND_DEMO      85
# WEATHER                 82
# HOUSE_AND_HOME          80
# ART_AND_DESIGN          65
# EVENTS                  64
# PARENTING               60
# COMICS                  60
# BEAUTY                  53
# ...
